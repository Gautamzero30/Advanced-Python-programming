# %%
import pandas as pd
import numpy as np

# %%
x=np.array([1000,100,200,300,400,500])
x_transformed=np.log1p(x)
print(x_transformed)
# Out:
# [6.90875478 4.61512052 5.30330491 5.70711026 5.99396143 6.2166061 ]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 0., 0., 0., 0., 1.]),
#  array([ 100.,  190.,  280.,  370.,  460.,  550.,  640.,  730.,  820.,
#          910., 1000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x_transformed)
# Out:
# (array([1., 0., 0., 1., 1., 0., 2., 0., 0., 1.]),
#  array([4.61512052, 4.84448394, 5.07384737, 5.3032108 , 5.53257422,
#         5.76193765, 5.99130107, 6.2206645 , 6.45002793, 6.67939135,
#         6.90875478]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import PowerTansformer
import numpy as np
x= np.array([-100,200,300,400,.500,6000])
pt= PowerTransformed
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.preprocessing import PowerTansformer
#       2 import numpy as np
#       3 x= np.array([-100,200,300,400,.500,6000])
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install sklearn
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.0 MB/s  0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
# ...

# %%
pip3 install sklearn
# Out:
#   Cell In[6], line 1
#     pip3 install sklearn
#          ^
# SyntaxError: invalid syntax

# %%
pip install scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 18.1 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 21.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# ...
# Note: you may need to restart the kernel to use updated packages.
